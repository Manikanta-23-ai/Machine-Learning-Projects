# %% [markdown]
# Project Overview: Iris Flower Classification in machine learning
# ![machine-learning-project-iris-flower-classification.webp](data:image/webp;base64,...)
#
# Objective:
# To develop a machine learning model that accurately classifies Iris flowers into one of three species—Setosa, Versicolor, or Virginica—based on four morphological features.
#
# Dataset:
# The Iris dataset comprises 150 samples, evenly distributed among three species:
#
# Iris Setosa
#
# Iris Versicolor
#
# Iris Virginica
#
# Each sample includes four features:
#
# Sepal Length (cm)
#
# Sepal Width (cm)
#
# Petal Length (cm)
#
# Petal Width (cm)

# %% [markdown]
#  Methodology iam follow :-->
#
# Data Exploration & Visualization:
#
# Examine dataset structure and summary statistics.
#
# Visualize feature distributions and relationships using histograms, pair plots, and correlation heatmaps.
#
# Data Preprocessing:
#
# Handle missing values and encode categorical labels.
#
# Split the dataset into training and testing sets.
#
# Model Building:
#
# *Apply various machine learning algorithms:
#
#    K-Nearest Neighbors (KNN)
#
#    Support Vector Machine (SVM)
#
#    Random Forest (RF)
#
#    Decision Tree (DT)
#
#    Gradient Boosting (GB)

# %% [markdown]
# # IMPORTING SOME OF THE LIBERARY'S
# # --> PANDAS
# # --> NUMPY
# # --> MATPLOT
# # --> SKLEARN

# %%
import pandas as pd #importing Pandas library
df=pd.read_csv('/content/IRIS Flower Data.csv')

# %% [markdown]
# # RETRIEVING THE FIRST 5 ROWS AND COLOMNS AND DESCRIBE THE DATA SET

# %%
df.head() #retrieve first 5 rows
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df.describe() # define the describe the data set
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# # Exploratory data Analaysis :
# THE EXPLORATORY DAT A ANALASIS IS DERCRIBE THE ENTIRE DATA SET IS SUMMERISED USING DATA VISUALIZATION AND STATASTIC TECHNIQUES
# THE The MAIN GOAL OF EDA IS PATTERN DETECTION AND SPOT ANAMOALIES

# %%
df['petal_length'].plot()#polting the Data
# Out:
# <Axes: >

# %%
df['sepal_width'].plot()
# Out:
# <Axes: >

# %%
df['sepal_length'].plot()
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# BAR CHARTS HELP TO QUICKLY UNDERSTAND AND COMPARE THE AMOUNTS OR COUNTS OF VARIOUS GROUPS OR CATEGORIES. FOR EXAMPLE, IN THE IRIS FLOWER CLASSIFICATION PROJECT, A BAR CHART SHOWS THE NUMBER OF FLOWER SAMPLES IN EACH SPECIES, ALLOWING US TO SEE IF THE DATA IS BALANCED OR IF ANY SPECIES HAS MORE OR FEWER SAMPLES.

# %%
colours =['red','green','blue','pink']
df['species'].value_counts(4).plot(kind='bar',color=colours)
# Out:
# <Axes: xlabel='species'>

# %% [markdown]
# A SCATTER PLOT IS A TYPE OF GRAPH THAT USES DOTS TO REPRESENT VALUES FOR TWO DIFFERENT VARIABLES. EACH DOT’S POSITION ON THE HORIZONTAL (X) AND VERTICAL (Y) AXES INDICATES THE VALUES OF THE TWO VARIABLES. SCATTER PLOTS ARE USED TO OBSERVE RELATIONSHIPS, TRENDS, OR CORRELATIONS BETWEEN VARIABLES.

# %%
for i in range(4):
  df.plot(kind='scatter',x='sepal_length',y='sepal_width',color=colours[i])

# %% [markdown]
# INSTALLING LIBRARIES LIKE MATPLOT AND SKLEARN

# %%
import sklearn as sns
import matplotlib as plt
df.plot(kind='scatter',x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
# !pip install sklearn as sns
# !pip install matplotlib as plt
# Out:
# ...
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...
# ERROR: Could not find a version that satisfies the requirement as (from versions: none)
# ERROR: No matching distribution found for as

# %% [markdown]
# # LABEL ENCODING OBJECTIVE
#
# THE OBJECTIVE OF LABEL ENCODING IS TO CONVERT THE CATEGORICAL TARGET VARIABLE—IN THIS CASE, THE IRIS FLOWER SPECIES (SETOZA, VERSICOLOR, VIRGINICA)—INTO A NUMERICAL FORMAT THAT MACHINE LEARNING ALGORITHMS CAN PROCESS. SINCE MANY ALGORITHMS REQUIRE NUMERICAL INPUTS, LABEL ENCODING ASSIGNS EACH UNIQUE CATEGORY A DISTINCT INTEGER VALUE, ENABLING THE MODEL TO EFFECTIVELY LEARN AND CLASSIFY THE SPECIES BASED ON THE ENCODED LABELS.

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['species']=le.fit_transform(df['species'])
df.head()
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2

# %% [markdown]
# TRAINING A MODEL REFERS TO THE PROCESS OF USING A SET OF DATA **CALLED THE TRAINING SET** TEACH A MACHINE LEARNING ALGORITHM TO RECOGNIZE PATTERNS AND RELATIONSHIPS BETWEEN INPUT FEATURES AND TARGET OUTPUTS. THE MODEL LEARNS FROM THIS DATA TO MAKE PREDICTIONS.
#
# TESTING A MODEL INVOLVES EVALUATING THE TRAINED MODEL ON A SEPARATE SET OF DATA **CALLED THE TEST SET** THAT IT HAS NEVER SEEN BEFORE, TO ASSESS HOW WELL IT CAN PREDICT NEW, UNSEEN DATA.

# %%
from sklearn.model_selection import train_test_split
x=df.drop('species',axis=1)
y=df['species']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %% [markdown]
# LOGISTIC REGRESSION IS A SUPERVISED MACHINE LEARNING ALGORITHM USED FOR CLASSIFICATION TASKS. IT PREDICTS THE PROBABILITY THAT A GIVEN INPUT BELONGS TO A PARTICULAR CATEGORY OR CLASS BY MODELING THE RELATIONSHIP BETWEEN ONE OR MORE INDEPENDENT VARIABLES AND A BINARY OR MULTICLASS DEPENDENT VARIABLE USING THE LOGISTIC FUNCTION (SIGMOID FUNCTION).

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
print(model.score(x_test,y_test))
# Out:
# 1.0

# %%
print(" Calculate Accuracy")
print("Accuracy is :",model.score(x_test,y_test)*100)
# Out:
#  Calculate Accuracy
# Accuracy is : 100.0

# %% [markdown]
# A CONFUSION MATRIX IS A TABLE USED TO EVALUATE THE PERFORMANCE OF A CLASSIFICATION MODEL. IT SHOWS THE NUMBER OF CORRECT AND INCORRECT PREDICTIONS MADE BY THE MODEL COMPARED TO THE ACTUAL CLASS LABELS. THE MATRIX DISPLAYS TRUE POSITIVES , TRUE NEGATIVES , FALSE POSITIVES , AND FALSE NEGATIVES.

# %%
from sklearn.metrics import confusion_matrix
y_pred=model.predict(x_test)
cm=confusion_matrix(y_test,y_pred)
print(cm)
# Out:
# [[11  0  0]
#  [ 0 11  0]
#  [ 0  0  8]]

# %% [markdown]
# K-NEAREST NEIGHBORS (KNN) CLASSIFIER IS A SIMPLE, SUPERVISED MACHINE LEARNING ALGORITHM USED FOR CLASSIFICATION AND REGRESSION TASKS. IT CLASSIFIES A DATA POINT BASED ON THE MAJORITY CLASS AMONG ITS 'K' CLOSEST NEIGHBORS IN THE FEATURE SPACE, WHERE 'K' IS A USER-DEFINED INTEGER

# %%
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train,y_train)
print("Accuracy :",model.score(x_test,y_test)*100)
# Out:
# Accuracy : 100.0

# %% [markdown]
# A DECISION TREE IS A SUPERVISED MACHINE LEARNING ALGORITHM USED FOR CLASSIFICATION AND REGRESSION TASKS. IT WORKS BY SPLITTING THE DATA INTO BRANCHES BASED ON FEATURE VALUES, FORMING A TREE-LIKE MODEL OF DECISIONS. EACH INTERNAL NODE REPRESENTS A TEST ON A FEATURE, EACH BRANCH REPRESENTS THE OUTCOME OF THE TEST, AND EACH LEAF NODE REPRESENTS A CLASS LABEL OR CONTINUOUS VALUE.

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print("Accuracy :",model.score(x_test,y_test)*100)
# Out:
# Accuracy : 96.66666666666667
